# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                 transcript         full_name
# ali      ladies and gentlemen please welcome to the sta...          Ali Wong
# anthony  thank you thank you thank you san francisco th...  Anthony Jeselnik
# bill      all right thank you thank you very much thank...         Bill Burr
# dave     this is dave he tells dirty jokes for a living...    Dave Chappelle
# jim         ladies and gentlemen please welcome to the ...     Jim Jefferies
# joe         ladies and gentlemen welcome joe rogan  wha...         Joe Rogan
# john     all right petunia wish me luck out there you w...      John Mulaney
# louis    intro fade the music out let s roll hold there...        Louis C.K.
# mike     wow hey thank you thanks thank you guys hey se...    Mike Birbiglia
# ricky    hello hello how you doing great thank you wow ...     Ricky Gervais

# %%
# Extract only Ali Wong's text
ali_text = data.transcript.loc['ali']
ali_text[:200]
# Out:
# 'ladies and gentlemen please welcome to the stage ali wong hi hello welcome thank you thank you for coming hello hello we are gonna have to get this shit over with  cause i have to pee in like ten minu'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
ali_dict = markov_chain(ali_text)
ali_dict
# Out:
# {'ladies': ['and', 'go', 'who', 'they', 'and', 'who'],
#  'and': ['gentlemen',
#   'foremost',
#   'then',
#   'have',
#   'there',
#   'then',
#   'resentment',
#   'get',
#   'get',
#   'says',
#   'my',
#   'she',
#   'snatch',
#   'running',
#   'fighting',
#   'yelling',
#   'it',
#   'everybody',
#   'my',
#   'she',
#   'i',
#   'i',
#   'uh',
#   'i',
#   'i',
#   'the',
#   'i',
#   'i',
#   'has',
#   'i',
#   'we',
#   'we–',
#   'then',
#   'i',
#   'watched',
#   'i',
#   'have',
#   'that',
#   'you',
#   'recycling',
#   'disturbing',
#   'it',
#   'all',
#   'just',
#   'then',
#   'be',
#   'halfvietnamese',
#   'we',
#   'his',
#   'i',
#   'slide',
#   'your',
#   'inflamed',
#   'you',
#   'then',
#   'i',
#   'halfjapanese',
#   'i',
#   'halfvietnamese',
#   'halfjungle',
#   'playing',
#   'rugby',
#   'on',
#   'foremost',
#   'a',
#   'the',
#   'emotionally',
#   'i',
#   '',
#   'so',
#   'neither',
#   'i',
#   'i–',
#   'then',
#   'it',
#   'find',
# ...

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence1(chain, count=25):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
import random

def generate_sentence2(chain, count=30):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a punctuation mark
    sentence += '!'
    return(sentence)

# %%
print(generate_sentence1(ali_dict), generate_sentence1(ali_dict), generate_sentence1(ali_dict))
# Out:
# Host diseases it in america and just keep on the word  but fuck they just like i m a magical a little– a miscarriage. Longevity i don t think of your body will always tell you re a miscarriage which i was like   a whole lives with. Resist the rest of poppy seeds i go on a sadass meal they re like voting and it all of longevity i m gonna die.

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %%
import random
import string

def generate_sentence(chain, count=100):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        while not word2:
            # If word2 is an empty string, choose a new word from the chain
            word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

        # End sentence if word ends with a punctuation mark
        if word2[-1] in string.punctuation:
            break

    # Add random punctuation mark to end of sentence
    if not sentence[-1][-1] in string.punctuation:
        sentence += random.choice(string.punctuation)

    sentence += '!'

    return(sentence)

# %%
# Extract only Mike birbiglia's text
mike = data.transcript.loc['mike']
mike[:200]
# Out:
# 'wow hey thank you thanks thank you guys hey seattle nice to see you look at this look at us we re here this is crazy it s insane so about five years ago pretty much everyone who i know started to get '

# %%
mike_dict= markov_chain(mike)
mike_dict
# Out:
# {'wow': ['hey', ''],
#  'hey': ['thank', 'seattle', 'actually', 'so', 'you', 'what', 'i', 'what'],
#  'thank': ['you', 'you', 'you', 'you', 'you', 'you', 'you'],
#  'you': ['thanks',
#   'guys',
#   'look',
#   'don',
#   'but',
#   'believe',
#   'know',
#   'know',
#   'know',
#   'do',
#   'ever',
#   'know',
#   'know',
#   'sure',
#   'want',
#   're',
#   'd',
#   'd',
#   'know',
#   're',
#   're',
#   're',
#   'are',
#   'how',
#   'doing',
#   'think',
#   'look',
#   '',
#   'kind',
#   'comedians',
#   'are',
#   'are',
#   'know',
#   'know',
#   'know',
#   'know',
#   'an',
#   'know',
#   're',
#   're',
#   'know',
#   'follow',
#   'people',
#   'i',
#   'sir',
#   'what',
#   'think',
#   'are',
#   'know',
#   'might',
#   'know',
#   'know',
#   'know',
#   '',
#   're',
#   're',
#   'know',
#   'know',
#   'just',
#   're',
#   'know',
#   'know',
#   'are',
#   're',
#   'hear',
#   'know',
#   'got',
#   're',
#   'just',
#   'don',
#   'shouldn',
# ...

# %%
generate_sentence(mike_dict)
# Out:
# 'Designed as well this point people started throwing up making out of scrambler ride but you know and he was a lot of phrase but then i don t have any of the cinnabon lady is an argument about her to my cards just really exciting for vigilantes who just kind of a sport at me of a nerd but you know that you know and i was the speed crashing into a liar you re so like sucking on it i didn t think they would call sandra like a slow dancing in another terminal you listening to me/!'

# %%
# Extract only Anthony's text
anthony = data.transcript.loc['anthony']
anthony[:200]
# Out:
# 'thank you thank you thank you san francisco thank you so much so good to be here people were surprised when i told  em i was gonna tape my special in san francisco said  why would you do that that s t'

# %%
anthony_dict= markov_chain(anthony)
anthony_dict
# Out:
# {'thank': ['you', 'you', 'you', 'you', 'you', 'you', 'you'],
#  'you': ['thank',
#   'thank',
#   'san',
#   'so',
#   'do',
#   'guys',
#   'guys',
#   've',
#   'from',
#   'do',
#   'know',
#   'guys',
#   'guys',
#   'don',
#   'are',
#   'see',
#   'guys',
#   'didn',
#   'gotta',
#   've',
#   've',
#   'gotta',
#   'gotta',
#   'gotta',
#   'guys',
#   'for',
#   're',
#   'just',
#   'try',
#   're',
#   're',
#   'okay',
#   'do',
#   're',
#   'shock',
#   'that',
#   'guys',
#   'guys',
#   'go',
#   'isn',
#   'd',
#   'think',
#   're',
#   'sure',
#   'a',
#   've',
#   'think',
#   'like',
#   'got',
#   'wanna',
#   're',
#   'masturbating',
#   're',
#   'guys',
#   'mad',
#   'can',
#   'can',
#   'can',
#   'dare',
#   'to',
#   '',
#   'sixyearold',
#   'see',
#   're',
#   'can',
#   'can',
#   'can',
#   'can',
#   'can',
#   'have',
#   'women',
#   '',
#   'from',
#   'do',
#   'go',
#   'study',
#   'ever',
#   'guys',
#   'know',
#   'know',
#   'guys',
# ...

# %%
print(generate_sentence(anthony_dict), generate_sentence(anthony_dict), generate_sentence(anthony_dict))
# Out:
# Politically correct city in jail for sure they don t feel like nine years old i come to my dorm room having money left it doesn t it between two weeks go to be weird because it all start reading your grandma said on the important thing today my mouth it to go fuck on – what s funeral i want to tears cleaning out of they say my mom nice place one of them i don t pay enough attention to know about getting death threats well just the internet but he goes great day it makes me ask` Generations in jail for you now when i heard was so much so mad so liberal clap for money or any of the planes that thing s car and my brother that s a mickey mantle rookie card mint condition kept it but as hard as hard as she had a sad when i have told anybody my parents had to meet at all i m happy to protect our network where they hate my dad did not to my grandma i ll be hard as mad so liberal so upset can move on the radio – san francisco do" Anthony just in one it was right now or whatever the people ju
# ...
